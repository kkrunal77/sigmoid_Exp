# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# result = ["Red", "Light Red"]
# result = list(set(result))
# result = list(filter(lambda x: [x for i in result if ' '+x+' ' in ' '+i+' ' and x != i] == [],result))
# print(result)

# %%
df = pd.read_csv("training_data.csv")
df = pd.read_csv("OnlineNewsPopularity.csv")
df_test = pd.read_csv("test_data.csv")

# %%
df.columns.tolist()
# Out:
# ['url',
#  'url_id',
#  ' timedelta',
#  ' n_tokens_title',
#  ' n_tokens_content',
#  ' n_unique_tokens',
#  ' n_non_stop_words',
#  ' n_non_stop_unique_tokens',
#  ' num_hrefs',
#  ' num_self_hrefs',
#  ' num_imgs',
#  ' num_videos',
#  ' average_token_length',
#  ' num_keywords',
#  ' data_channel_is_lifestyle',
#  ' data_channel_is_entertainment',
#  ' data_channel_is_bus',
#  ' data_channel_is_socmed',
#  ' data_channel_is_tech',
#  ' data_channel_is_world',
#  ' kw_min_min',
#  ' kw_max_min',
#  ' kw_avg_min',
#  ' kw_min_max',
#  ' kw_max_max',
#  ' kw_avg_max',
#  ' kw_min_avg',
#  ' kw_max_avg',
#  ' kw_avg_avg',
#  ' self_reference_min_shares',
#  ' self_reference_max_shares',
#  ' self_reference_avg_sharess',
#  ' weekday_is_monday',
#  ' weekday_is_tuesday',
#  ' weekday_is_wednesday',
#  ' weekday_is_thursday',
#  ' weekday_is_friday',
#  ' weekday_is_saturday',
#  ' weekday_is_sunday',
#  ' is_weekend',
#  ' LDA_00',
#  ' LDA_01',
#  ' LDA_02',
#  ' LDA_03',
# ...

# %%
df = df[[' timedelta', ' n_tokens_title', ' n_tokens_content',
       ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
       ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
       ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
       ' data_channel_is_entertainment', ' data_channel_is_bus',
       ' data_channel_is_socmed', ' data_channel_is_tech',
       ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
       ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
       ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
       ' self_reference_max_shares', ' self_reference_avg_sharess',
       ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
       ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
       ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
       ' LDA_03', ' LDA_04', ' global_subjectivity',
       ' global_sentiment_polarity', ' global_rate_positive_words',
       ' global_rate_negative_words', ' rate_positive_words',
       ' rate_negative_words', ' avg_positive_polarity',
       ' min_positive_polarity', ' max_positive_polarity',
       ' avg_negative_polarity', ' min_negative_polarity',
       ' max_negative_polarity', ' title_subjectivity',
       ' title_sentiment_polarity', ' abs_title_subjectivity',
       ' abs_title_sentiment_polarity', " shares"]]

# %%
df.describe()
# Out:
#           timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# count  39644.000000     39644.000000       39644.000000      39644.000000
# mean     354.530471        10.398749         546.514731          0.548216
# std      214.163767         2.114037         471.107508          3.520708
# min        8.000000         2.000000           0.000000          0.000000
# 25%      164.000000         9.000000         246.000000          0.470870
# 50%      339.000000        10.000000         409.000000          0.539226
# 75%      542.000000        12.000000         716.000000          0.608696
# max      731.000000        23.000000        8474.000000        701.000000
#
#         n_non_stop_words   n_non_stop_unique_tokens     num_hrefs  \
# count       39644.000000               39644.000000  39644.000000
# mean            0.996469                   0.689175     10.883690
# std             5.231231                   3.264816     11.332017
# ...

# %%
X_test_linear = df_test[[' timedelta', ' n_tokens_title', ' n_tokens_content',
       ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
       ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
       ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
       ' data_channel_is_entertainment', ' data_channel_is_bus',
       ' data_channel_is_socmed', ' data_channel_is_tech',
       ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
       ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
       ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
       ' self_reference_max_shares', ' self_reference_avg_sharess',
       ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
       ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
       ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
       ' LDA_03', ' LDA_04', ' global_subjectivity',
       ' global_sentiment_polarity', ' global_rate_positive_words',
       ' global_rate_negative_words', ' rate_positive_words',
       ' rate_negative_words', ' avg_positive_polarity',
       ' min_positive_polarity', ' max_positive_polarity',
       ' avg_negative_polarity', ' min_negative_polarity',
       ' max_negative_polarity', ' title_subjectivity',
       ' title_sentiment_polarity', ' abs_title_subjectivity',
       ' abs_title_sentiment_polarity']]

# %%
# df = df[df[" shares"]<=600000]

# %%
X = df[[' timedelta', ' n_tokens_title', ' n_tokens_content',
       ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
       ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
       ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
       ' data_channel_is_entertainment', ' data_channel_is_bus',
       ' data_channel_is_socmed', ' data_channel_is_tech',
       ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
       ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
       ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
       ' self_reference_max_shares', ' self_reference_avg_sharess',
       ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
       ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
       ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
       ' LDA_03', ' LDA_04', ' global_subjectivity',
       ' global_sentiment_polarity', ' global_rate_positive_words',
       ' global_rate_negative_words', ' rate_positive_words',
       ' rate_negative_words', ' avg_positive_polarity',
       ' min_positive_polarity', ' max_positive_polarity',
       ' avg_negative_polarity', ' min_negative_polarity',
       ' max_negative_polarity', ' title_subjectivity',
       ' title_sentiment_polarity', ' abs_title_subjectivity',
       ' abs_title_sentiment_polarity']]

Y = df[[" shares"]]


from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X,Y, test_size=0.2)

# %%
plt.plot(Xtrain, Ytrain, '.')
plt.axis()
plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt

# # Fixing random state for reproducibility
# # np.random.seed(19680801)

# # mu, sigma = 100, 15
# # x = mu + sigma * np.random.randn(10000)

# # the histogram of the data
# df_kk = df[:100] 
# for i in df_kk.columns.tolist():
#     n, bins, patches = plt.hist(df_kk[[i]],1000, normed=1, facecolor='g', alpha=0.75)
    
#     plt.xlabel('Count')
#     plt.ylabel('Frequency')
#     plt.title(i)

#     # plt.grid(True)
#     plt.show()

# %% [markdown]
# # Session_1

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# from jyquickhelper import add_notebook_menu
# add_notebook_menu()

# %%
import pandas
data = df
data.columns = [c.strip() for c in data.columns]  # remove spaces around data
data.head()
# Out:
#    timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 0        731              12               219         0.663594
# 1        731               9               255         0.604743
# 2        731               9               211         0.575130
# 3        731               9               531         0.503788
# 4        731              13              1072         0.415646
#
#    n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 0               1.0                  0.815385          4               2
# 1               1.0                  0.791946          3               1
# 2               1.0                  0.663866          3               1
# 3               1.0                  0.665635          9               0
# 4               1.0                  0.540890         19              19
#
#    num_imgs  num_videos   ...    min_positive_polarity  max_positive_polarity  \
# ...

# %%
data.shape
# Out:
# (39644, 60)

# %%
import numpy
numeric = [c for i,c in enumerate(data.columns) if data.dtypes[i] in [numpy.float64, numpy.int64]]
len(numeric)
# Out:
# 60

# %%
#correlation in data using seaborn graphical representation.

# %%
import seaborn
cmap = seaborn.diverging_palette(h_neg=210, h_pos=350, s=90, l=30, as_cmap=True, center="light")
seaborn.clustermap(data[numeric].corr(), figsize=(14, 14), cmap=cmap);

# %%
#Visulization through each of the columns, analizing distribution across filed.

# %%
import seaborn
seaborn.pairplot(data[numeric[:5]]);

# %%
data[data.n_unique_tokens > 100]
# Out:
#        timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# 31037        142               9              1570            701.0
#
#        n_non_stop_words  n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  \
# 31037            1042.0                     650.0         11              10
#
#        num_imgs  num_videos   ...    min_positive_polarity  \
# 31037        51           0   ...                      0.0
#
#        max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# 31037                    0.0                    0.0                    0.0
#
#        max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# 31037                    0.0                 0.0                       0.0
#
#        abs_title_subjectivity  abs_title_sentiment_polarity  shares
# 31037                     0.0                           0.0    5900
#
# [1 rows x 60 columns]

# %%
data_clean = data[data.n_unique_tokens < 100].copy()
#

# %%
# data_clean = df

# %%
seaborn.pairplot(data_clean[numeric[:5]]);

# %%
seaborn.pairplot(data_clean[numeric[5:15]])

# %%
data_clean.hist(figsize=(16,16));

# %%
#data scaling
#performing data scaling scross really large distributed which id 50% of data that will make impect on targer variable
#data scaling in logarithmic scale

# %%
desc = data_clean.describe().T
desc["log"] = (desc["max"] > desc["50%"] * 9) & (desc["max"] > 1)
desc["scale"] = ""
desc.loc[desc["log"],"scale"] = "log"
desc[["mean", "min", "50%", "max", "scale"]]
# Out:
#                                         mean       min            50%  \
# timedelta                         354.535832  8.000000     339.000000
# n_tokens_title                     10.398784  2.000000      10.000000
# n_tokens_content                  546.488914  0.000000     409.000000
# n_unique_tokens                     0.530547  0.000000       0.539216
# n_non_stop_words                    0.970209  0.000000       1.000000
# n_non_stop_unique_tokens            0.672796  0.000000       0.690476
# num_hrefs                          10.883687  0.000000       8.000000
# num_self_hrefs                      3.293469  0.000000       3.000000
# num_imgs                            4.542971  0.000000       1.000000
# num_videos                          1.249905  0.000000       0.000000
# average_token_length                4.548236  0.000000       4.664078
# num_keywords                        7.223772  1.000000       7.000000
# ...

# %%
# import numpy
# numpy.log(data_clean["shares"]).hist(bins=50);

# %%
shares = data_clean[[c for c in numeric if "share" in c]].copy()
for c in shares.columns:
    shares[c] = numpy.log(shares[c] + 1)
seaborn.pairplot(shares);

# %%
kw = data_clean[[c for c in numeric if "kw" in c]].copy()
#for c in shares.columns:
#    shares[c] = numpy.log(shares[c] + 1)
seaborn.pairplot(kw);

# %%
# data_clean = data[data.n_unique_tokens < 100].copy()

# %%
#data scaling
#performing data scaling scross really large distributed which id 50% of data that will make impect on targer variable
#data scaling in logarithmic scale 
# "kw_min_min" and "kw_avg_min" suppressing these features whith log2 scale.

# %%
desc = data_clean.describe().T
desc["log"] = (desc["max"] > desc["50%"] * 9) & (desc["max"] > 1)
desc["log+2"] = desc["log"] & (desc["min"] < 0)
desc["scale"] = ""
desc.loc[desc["log"],"scale"] = "log"
desc.loc[desc["log+2"],"scale"] = "log+2"
desc[["mean", "min", "50%", "max", "scale"]]
# Out:
#                                         mean       min            50%  \
# timedelta                         354.535832  8.000000     339.000000
# n_tokens_title                     10.398784  2.000000      10.000000
# n_tokens_content                  546.488914  0.000000     409.000000
# n_unique_tokens                     0.530547  0.000000       0.539216
# n_non_stop_words                    0.970209  0.000000       1.000000
# n_non_stop_unique_tokens            0.672796  0.000000       0.690476
# num_hrefs                          10.883687  0.000000       8.000000
# num_self_hrefs                      3.293469  0.000000       3.000000
# num_imgs                            4.542971  0.000000       1.000000
# num_videos                          1.249905  0.000000       0.000000
# average_token_length                4.548236  0.000000       4.664078
# num_keywords                        7.223772  1.000000       7.000000
# ...

# %%
import numpy
new_data = data_clean.copy()
for c in desc.index [ desc["scale"] == "log"]:
    new_data[c] = numpy.log(new_data[c] + 1)
for c in desc.index [ desc["scale"] == "log+2"]:
    new_data[c] = numpy.log(new_data[c] + 2)

# %%
for i in new_data.columns.tolist():
    print(i)
# Out:
# timedelta
# n_tokens_title
# n_tokens_content
# n_unique_tokens
# n_non_stop_words
# n_non_stop_unique_tokens
# num_hrefs
# num_self_hrefs
# num_imgs
# num_videos
# average_token_length
# num_keywords
# data_channel_is_lifestyle
# data_channel_is_entertainment
# data_channel_is_bus
# data_channel_is_socmed
# data_channel_is_tech
# data_channel_is_world
# kw_min_min
# kw_max_min
# kw_avg_min
# kw_min_max
# kw_max_max
# kw_avg_max
# kw_min_avg
# kw_max_avg
# kw_avg_avg
# self_reference_min_shares
# self_reference_max_shares
# self_reference_avg_sharess
# weekday_is_monday
# weekday_is_tuesday
# weekday_is_wednesday
# weekday_is_thursday
# weekday_is_friday
# weekday_is_saturday
# weekday_is_sunday
# is_weekend
# LDA_00
# LDA_01
# LDA_02
# LDA_03
# LDA_04
# global_subjectivity
# global_sentiment_polarity
# global_rate_positive_words
# global_rate_negative_words
# rate_positive_words
# rate_negative_words
# avg_positive_polarity
# min_positive_polarity
# max_positive_polarity
# ...

# %%
numpy.log(2)
# np.log(1*3)/np.log(1)
# import math
# math.log(**3, 42)
# Out:
# 0.69314718055994529

# %%
# np.exp(7.125314892)

# %%
new_data.shape
# Out:
# (39643, 60)

# %%
set(new_data.dtypes)
# Out:
# {dtype('int64'), dtype('float64')}

# %%
from sklearn.model_selection import train_test_split

features = new_data[['timedelta',
                     'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens',
                     'n_tokens_title',
                     'n_tokens_content',
                     'num_hrefs',
                     'num_self_hrefs',
                     'num_imgs',
                     'num_videos',
                     'average_token_length',
                     'num_keywords',
                     'data_channel_is_lifestyle',
                     'data_channel_is_entertainment',
                     'data_channel_is_bus',
                     'data_channel_is_socmed',
                     'data_channel_is_tech',
                     'data_channel_is_world',
                     'kw_min_min',
                     'kw_max_min',
                     'kw_avg_min',
                     'kw_min_max',
                     'kw_max_max',
                     'kw_avg_max',
                     'kw_min_avg',
                     'kw_max_avg',
                     'kw_avg_avg',
                     'self_reference_min_shares',
                     'self_reference_max_shares',
                     'self_reference_avg_sharess',
                     'weekday_is_monday',
                     'weekday_is_tuesday',
                     'weekday_is_wednesday',
                     'weekday_is_thursday',
                     'weekday_is_friday',
                     'weekday_is_saturday',
                     'weekday_is_sunday',
                     'is_weekend',
                     'LDA_00',
                     'LDA_01',
                     'LDA_02',
                     'LDA_03',
                     'LDA_04',
                     'global_subjectivity',
                     'global_sentiment_polarity',
                     'global_rate_positive_words',
                     'global_rate_negative_words',
                     'rate_positive_words',
                     'rate_negative_words',
                     'avg_positive_polarity',
                     'min_positive_polarity',
                     'max_positive_polarity',
                     'avg_negative_polarity',
                     'min_negative_polarity',
                     'max_negative_polarity',
                     'title_subjectivity',
                     'title_sentiment_polarity',
                     'abs_title_subjectivity',
                     'abs_title_sentiment_polarity']]
target = new_data["shares"]

#apliting data in traning and test set by retion of 30%.
X_train, X_test, y_train, y_test = train_test_split(features, target)

# %%
# features

# %%
plt.plot(X_train, y_train, '.')
plt.axis()
plt.show()

# %%
#old plot
plt.plot(X_train, y_train, '.')
plt.axis()
plt.show()

# %%
plt.plot(X_train, y_train, '.')
plt.axis()
plt.show()

# %% [markdown]
# # Decision Trees

# %%
from sklearn import tree

# %%
D_tree = tree.DecisionTreeClassifier()

# %%
D_tree = D_tree.fit(X_train, [int(round(i,0)) for i in y_train])

# %%
print(mean_absolute_percentage_error(D_tree.predict(X_test), [int(i) for i in y_test]))
# Out:
# 12.7596682457

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
clr = RandomForestRegressor(min_samples_leaf=20, n_estimators=75, max_depth=7, min_weight_fraction_leaf=0.001, min_samples_split=20)
clr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=7,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=20, min_samples_split=20,
#            min_weight_fraction_leaf=0.001, n_estimators=75, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# # mean absolute percentage error calculator

# %%
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# df_test['predictions'] = clr.predict(X_test_linear).tolist()
# # df_test['shares'] = [round(np.abs(i[0]),0) for i in df_test['predictions']]
# df_submit = df_test[["url_id","shares"]]
# df_submit.to_csv("RF_submission.csv",index=False)

print(mean_absolute_percentage_error(clr.predict(X_test).tolist(), y_test))


df_test['shares'] = clr.predict(X_test_linear).tolist()
# df_test['shares'] = [round(np.abs(i[0]),0) for i in df_test['predictions']]
df_test['shares'] = [np.exp(i) for i in df_test['shares']]
df_submit = df_test[["url_id","shares"]]

df_submit.to_csv("RandomForestRegressor_submission.csv",index=False)
# Out:
# 8.4120709403

# %%
tpredicted = clr.predict(X_train)
df = pandas.DataFrame()
df["train_predicted"] = tpredicted
df["train_expected"] = y_train
df.corr()
# Out:
#                  train_predicted  train_expected
# train_predicted         1.000000       -0.011469
# train_expected         -0.011469        1.000000

# %%
df = pandas.DataFrame()
df["test_predicted"] = clr.predict(X_test)
df["test_expected"] = y_test
df.corr()
# Out:
#                 test_predicted  test_expected
# test_predicted        1.000000       0.033959
# test_expected         0.033959       1.000000

# %%
df.plot(x ="test_expected", y="test_predicted", kind="scatter");

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(mean_absolute_percentage_error(linear.predict(X_test).tolist(), y_test))

df_test['shares'] = linear.predict(X_test_linear).tolist()
# df_test['shares'] = [round(np.abs(i[0]),0) for i in df_test['predictions']]
df_test['shares'] = [np.exp(i) for i in df_test['shares']]
df_submit = df_test[["url_id","shares"]]

df_submit.to_csv("LinearRegression_submission.csv",index=False)
# Out:
# 8.58020951119
# /home/kk/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in exp
#   """

# %% [markdown]
# # GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
est = GradientBoostingRegressor(min_samples_leaf=20, n_estimators=50, min_weight_fraction_leaf=0.01, min_samples_split=10)
est.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=20,
#              min_samples_split=10, min_weight_fraction_leaf=0.01,
#              n_estimators=50, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
# for i , j in zip()

# %%
np.exp([1,2,3,4,6])
# Out:
# array([   2.71828183,    7.3890561 ,   20.08553692,   54.59815003,
#         403.42879349])

# %%
print(mean_absolute_percentage_error(est.predict(X_test).tolist(), y_test))

df_test['shares'] = est.predict(X_test_linear).tolist()
# df_test['shares'] = [round(np.abs(i[0]),0) for i in df_test['predictions']]
# df_test['shares'] = [np.exp(i) for i in df_test['shares']]
df_submit = df_test[["url_id","shares"]]

df_submit.to_csv("GradientBoostingRegressor_submission.csv",index=False)
# Out:
# 8.44345452025

# %%
# df_submit

# %%
tpredicted = est.predict(X_train)
df = pandas.DataFrame()
df["train_predicted"] = tpredicted
df["train_expected"] = y_train
df.corr()
# Out:
#                  train_predicted  train_expected
# train_predicted         1.000000       -0.008284
# train_expected         -0.008284        1.000000

# %%
df = pandas.DataFrame()
df["train_predicted"] = est.predict(X_train)
df["train_expected"] = y_train
df.corr()
# Out:
#                  train_predicted  train_expected
# train_predicted         1.000000       -0.008284
# train_expected         -0.008284        1.000000

# %% [markdown]
# # xgboost

# %%
import xgboost
clxg = xgboost.XGBRegressor(max_depth=10, learning_rate=0.3, n_estimators=50)
clxg.fit(X_train, y_train)
# clr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.3, max_delta_step=0,
#        max_depth=10, min_child_weight=1, missing=None, n_estimators=50,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
X_train.columns.tolist()
# Out:
# ['url_id',
#  'timedelta',
#  'n_tokens_title',
#  'n_tokens_content',
#  'num_hrefs',
#  'num_self_hrefs',
#  'num_imgs',
#  'num_videos',
#  'average_token_length',
#  'num_keywords',
#  'data_channel_is_lifestyle',
#  'data_channel_is_entertainment',
#  'data_channel_is_bus',
#  'data_channel_is_socmed',
#  'data_channel_is_tech',
#  'data_channel_is_world',
#  'kw_min_min',
#  'kw_max_min',
#  'kw_avg_min',
#  'kw_min_max',
#  'kw_max_max',
#  'kw_avg_max',
#  'kw_min_avg',
#  'kw_max_avg',
#  'kw_avg_avg',
#  'self_reference_min_shares',
#  'self_reference_max_shares',
#  'self_reference_avg_sharess',
#  'weekday_is_monday',
#  'weekday_is_tuesday',
#  'weekday_is_wednesday',
#  'weekday_is_thursday',
#  'weekday_is_friday',
#  'weekday_is_saturday',
#  'weekday_is_sunday',
#  'is_weekend',
#  'LDA_00',
#  'LDA_01',
#  'LDA_02',
#  'LDA_03',
#  'LDA_04',
#  'global_subjectivity',
#  'global_sentiment_polarity',
#  'global_rate_positive_words',
#  'global_rate_negative_words',
# ...

# %%
X_test_linear.columns = ['url_id',
 'timedelta',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',

 'n_tokens_title',
 'n_tokens_content',
#  'n_unique_tokens',
#  'n_non_stop_words',
#  'n_non_stop_unique_tokens',
 'num_hrefs',
 'num_self_hrefs',
 'num_imgs',
 'num_videos',
 'average_token_length',
 'num_keywords',
 'data_channel_is_lifestyle',
 'data_channel_is_entertainment',
 'data_channel_is_bus',
 'data_channel_is_socmed',
 'data_channel_is_tech',
 'data_channel_is_world',
 'kw_min_min',
 'kw_max_min',
 'kw_avg_min',
 'kw_min_max',
 'kw_max_max',
 'kw_avg_max',
 'kw_min_avg',
 'kw_max_avg',
 'kw_avg_avg',
 'self_reference_min_shares',
 'self_reference_max_shares',
 'self_reference_avg_sharess',
 'weekday_is_monday',
 'weekday_is_tuesday',
 'weekday_is_wednesday',
 'weekday_is_thursday',
 'weekday_is_friday',
 'weekday_is_saturday',
 'weekday_is_sunday',
 'is_weekend',
 'LDA_00',
 'LDA_01',
 'LDA_02',
 'LDA_03',
 'LDA_04',
 'global_subjectivity',
 'global_sentiment_polarity',
 'global_rate_positive_words',
 'global_rate_negative_words',
 'rate_positive_words',
 'rate_negative_words',
 'avg_positive_polarity',
 'min_positive_polarity',
 'max_positive_polarity',
 'avg_negative_polarity',
 'min_negative_polarity',
 'max_negative_polarity',
 'title_subjectivity',
 'title_sentiment_polarity',
 'abs_title_subjectivity',
 'abs_title_sentiment_polarity']

# %%
# X_test_linear

# %%
print(mean_absolute_percentage_error(np.exp(clxg.predict(X_test).tolist()), y_test))

df_test['shares'] = clxg.predict(X_test_linear).tolist()
df_test['shares'] = [np.exp(i) for i in df_test['shares']]
df_submit = df_test[["url_id","shares"]]

df_submit.to_csv("XGBRegressor_submission.csv",index=False)
# Out:
# 99.5275133579

# %%
xgpredicted = clxg.predict(X_train)
df = pandas.DataFrame()
df["train_predicted"] = xgpredicted
df["train_expected"] = y_train
df.corr()
# Out:
#                  train_predicted  train_expected
# train_predicted         1.000000       -0.007195
# train_expected         -0.007195        1.000000
